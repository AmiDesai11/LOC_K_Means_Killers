# %%
import pandas as pd
import requests
from textblob import TextBlob
from dotenv import load_dotenv
import spacy
from fuzzywuzzy import process
import re

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# Load API keys from environment variable or any other source
api_keys = ["c016e6eeff684982bcfdef26b326c2b7", "5c8422ca2b604f4481e4a43aa95bb074", "cc7baa3c527f4624873dc8f237b2df5e", "060a295073e94514a268c437f2d0fc64", "67a4bf1c0713482fb55ad691623aab49", "a40ac68e681949d28f84e7152cb56d64", "c223bf69c1d24884ad47c00ffe4b4edc"]
current_key_index = 0

def get_api_key():
    global current_key_index
    api_key = api_keys[current_key_index]
    current_key_index = (current_key_index + 1) % len(api_keys)
    return api_key

# Load dataframes
stock_df = pd.read_csv("Stock_DataFrame.csv")
def_df = pd.read_csv("Sector_Definitions.csv")

# Define basic industry categories
basic_ind = def_df["Basic Industry"].apply(lambda x: x.replace("\n", "")
                                                    .replace("&", "& ")
                                                    .replace("/", "/ ")
                                                    .replace("  ", " ")).unique()

# Define the pre-defined categories for investors and politicians
categories = {industry: [industry] for industry in basic_ind}

# Function to perform sentiment analysis
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity == 0:
        return "Neutral"
    else:
        return "Negative"

# Function to fetch news data
def fetch_news_data():
    news_data = []
    for category, keywords in categories.items():
        print(f"Fetching articles for category: {category}")
        for keyword in keywords:
            url = f"https://newsapi.org/v2/everything?q=India+{keyword}&from=2024-03-08&to=2024-03-09&sortBy=publishedAt&apiKey={get_api_key()}"
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()
                articles = data["articles"][:5]  # Limit to 5 articles per category
                print(f"Number of articles fetched for {category}: {len(articles)}")
                for article in articles:
                    news_data.append({
                        "Category": category,
                        "News Headline": article["title"],
                        "Sentiment": get_sentiment(article["title"])
                    })
            elif response.status_code == 429:  # Rate Limit Exceeded
                print("API Rate Limit Exceeded. Trying with another API key...")
                continue
            else:
                print(f"Failed to fetch articles for {category}. Status code: {response.status_code}")
    return pd.DataFrame(news_data)

# Get news data and display
news_df = fetch_news_data()

# Process sector definitions
def_df["Basic Industry"] = def_df["Basic Industry"].apply(lambda x: x.replace("\n", "")
                                                    .replace("&", "& ")
                                                    .replace("/", "/ ")
                                                    .replace("  ", " "))

# Merge news data with sector definitions
merged_news_df = pd.merge(news_df, def_df[["Basic Industry", "Sector"]], left_on="Category", right_on="Basic Industry", how="left")
merged_news_df.drop(["Basic Industry"], axis=1, inplace=True)

# Function to find similar sector or industry
def find_similar_sector_or_industry(query, choices):
    match = process.extractOne(query, choices)
    return match[0] if match else None


# Iterate through merged_news_df to add Ticker
tickers = []
for index, row in merged_news_df.iterrows():
    sector = row['Sector']
    ticker = None
    
    # Try direct mapping first
    direct_mapping = stock_df.loc[stock_df['Sector'] == sector, 'Ticker']
    if not direct_mapping.empty:
        ticker = direct_mapping.iloc[0]
    else:
        # If direct mapping fails, find similar sector using fuzzy matching
        similar_sector = find_similar_sector_or_industry(sector, stock_df['Sector'])
        if similar_sector:
            similar_mapping = stock_df.loc[stock_df['Sector'] == similar_sector, 'Ticker']
            if not similar_mapping.empty:
                ticker = similar_mapping.iloc[0]
    
    tickers.append(ticker)

merged_news_df['Ticker'] = tickers

# Merge with stock_df to get Name
final_news_df = pd.merge(merged_news_df, stock_df[["Ticker", "Name"]], on="Ticker", how="left")
final_news_df["Sector"] = final_news_df["Sector"].apply(lambda x: x.replace("\n", " "))

# Save the final dataframe to CSV
final_news_df.to_csv(r"C:\Users\DELL\Desktop\Projects\LOC 6.0\Final News DataFrame\Basic Industry DataFrame.csv", index=False)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Fetching articles for category: CommodityChemicals
# Number of articles fetched for CommodityChemicals: 0
# Fetching articles for category: SpecialtyChemicals
# Number of articles fetched for SpecialtyChemicals: 0
# Fetching articles for category: Carbon Black
# Number of articles fetched for Carbon Black: 3
# Fetching articles for category: Dyes And Pigments
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Explosives
# Number of articles fetched for Explosives: 3
# Fetching articles for category: Petrochemicals
# Number of articles fetched for Petrochemicals: 4
# Fetching articles for category: Printing Inks
# Number of articles fetched for Printing Inks: 2
# Fetching articles for category: Trading - Chemicals
# Number of articles fetched for Trading - Chemicals: 2
# Fetching articles for category: Industrial Gases
# Number of articles fetched for Industrial Gases: 4
# Fetching articles for category: Fertilizers
# Number of articles fetched for Fertilizers: 5
# Fetching articles for category: Pesticides & Agrochemicals
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Cement & CementProducts
# Number of articles fetched for Cement & CementProducts: 5
# Fetching articles for category: Other ConstructionMaterials
# Number of articles fetched for Other ConstructionMaterials: 0
# Fetching articles for category: Ferro & SilicaManganese
# Number of articles fetched for Ferro & SilicaManganese: 0
# Fetching articles for category: Pig Iron
# Number of articles fetched for Pig Iron: 0
# Fetching articles for category: Sponge Iron
# Number of articles fetched for Sponge Iron: 0
# Fetching articles for category: Iron & Steel
# Number of articles fetched for Iron & Steel: 5
# Fetching articles for category: Aluminium
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Copper
# Number of articles fetched for Copper: 5
# Fetching articles for category: Zinc
# Number of articles fetched for Zinc: 5
# Fetching articles for category: Precious Metals
# Number of articles fetched for Precious Metals: 5
# Fetching articles for category: Diversified Metals
# Number of articles fetched for Diversified Metals: 0
# Fetching articles for category: Industrial Minerals
# Number of articles fetched for Industrial Minerals: 1
# Fetching articles for category: Trading - Metals
# Number of articles fetched for Trading - Metals: 2
# Fetching articles for category: Trading - Minerals
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Paper & PaperProducts
# Number of articles fetched for Paper & PaperProducts: 5
# Fetching articles for category: Forest Products
# Number of articles fetched for Forest Products: 1
# Fetching articles for category: Jute & JuteProducts
# Number of articles fetched for Jute & JuteProducts: 0
# Fetching articles for category: Passenger Cars & Utility Vehicles
# Number of articles fetched for Passenger Cars & Utility Vehicles: 2
# Fetching articles for category: 2/ 3 Wheelers
# Number of articles fetched for 2/ 3 Wheelers: 0
# Fetching articles for category: Auto Dealer
# Number of articles fetched for Auto Dealer: 0
# Fetching articles for category: Auto Components& Equipments
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Tyres & RubberProducts
# Number of articles fetched for Tyres & RubberProducts: 1
# Fetching articles for category: Trading - AutoComponents
# Number of articles fetched for Trading - AutoComponents: 0
# Fetching articles for category: Cycles
# Number of articles fetched for Cycles: 5
# Fetching articles for category: ConsumerElectronics
# Number of articles fetched for ConsumerElectronics: 0
# Fetching articles for category: Gems, JewelleryAnd Watches
# Number of articles fetched for Gems, JewelleryAnd Watches: 0
# Fetching articles for category: Glass - Consumer
# Number of articles fetched for Glass - Consumer: 2
# Fetching articles for category: HouseholdAppliances
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Houseware
# Number of articles fetched for Houseware: 0
# Fetching articles for category: Leather AndLeather Products
# Number of articles fetched for Leather AndLeather Products: 0
# Fetching articles for category: Leisure Products
# Number of articles fetched for Leisure Products: 1
# Fetching articles for category: Plastic Products -Consumer
# Number of articles fetched for Plastic Products -Consumer: 1
# Fetching articles for category: Plywood Boards/ Laminates
# Number of articles fetched for Plywood Boards/ Laminates: 0
# Fetching articles for category: Sanitary Ware
# Number of articles fetched for Sanitary Ware: 0
# Fetching articles for category: Paints
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Diversifiedconsumer products
# Number of articles fetched for Diversifiedconsumer products: 0
# Fetching articles for category: Footwear
# Number of articles fetched for Footwear: 1
# Fetching articles for category: Furniture, HomeFurnishing
# Number of articles fetched for Furniture, HomeFurnishing: 0
# Fetching articles for category: Ceramics
# Number of articles fetched for Ceramics: 3
# Fetching articles for category: Granites & Marbles
# Number of articles fetched for Granites & Marbles: 0
# Fetching articles for category: Garments & Apparels
# Number of articles fetched for Garments & Apparels: 0
# Fetching articles for category: Other TextileProducts
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Trading - TextileProducts
# Number of articles fetched for Trading - TextileProducts: 0
# Fetching articles for category: Advertising & Media Agencies
# Number of articles fetched for Advertising & Media Agencies: 5
# Fetching articles for category: Electronic Media
# Number of articles fetched for Electronic Media: 5
# Fetching articles for category: Web based mediaand service
# Number of articles fetched for Web based mediaand service: 0
# Fetching articles for category: Print Media
# Number of articles fetched for Print Media: 2
# Fetching articles for category: Film Production,Distribution & Exhibition
# Number of articles fetched for Film Production,Distribution & Exhibition: 0
# Fetching articles for category: DigitalEntertainment
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Media & Entertainment
# Number of articles fetched for Media & Entertainment: 5
# Fetching articles for category: TV Broadcasting & SoftwareProduction
# Number of articles fetched for TV Broadcasting & SoftwareProduction: 1
# Fetching articles for category: Printing & Publication
# Number of articles fetched for Printing & Publication: 5
# Fetching articles for category: Residential,CommercialProjects
# Number of articles fetched for Residential,CommercialProjects: 0
# Fetching articles for category: Real Estate relatedservices
# Number of articles fetched for Real Estate relatedservices: 0
# Fetching articles for category: Real EstateInvestment Trusts(REITs)
# Number of articles fetched for Real EstateInvestment Trusts(REITs): 0
# Fetching articles for category: Hotels & Resorts
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Restaurants
# Number of articles fetched for Restaurants: 5
# Fetching articles for category: Amusement Parks/ Other Recreation
# Number of articles fetched for Amusement Parks/ Other Recreation: 0
# Fetching articles for category: Wellness
# Number of articles fetched for Wellness: 5
# Fetching articles for category: Tour, TravelRelated Services
# Number of articles fetched for Tour, TravelRelated Services: 0
# Fetching articles for category: Education
# Number of articles fetched for Education: 5
# Fetching articles for category: E-Learning
# Number of articles fetched for E-Learning: 5
# Fetching articles for category: Food StorageFacilities
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Other ConsumerServices
# Number of articles fetched for Other ConsumerServices: 0
# Fetching articles for category: Speciality Retail
# Number of articles fetched for Speciality Retail: 0
# Fetching articles for category: Pharmacy Retail
# Number of articles fetched for Pharmacy Retail: 2
# Fetching articles for category: Diversified Retail
# Number of articles fetched for Diversified Retail: 1
# Fetching articles for category: E-Retail/ E-Commerce
# Number of articles fetched for E-Retail/ E-Commerce: 5
# Fetching articles for category: Internet & Catalogue Retail
# Number of articles fetched for Internet & Catalogue Retail: 5
# Fetching articles for category: Distributors
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: GasTransmission/ Marketing
# Number of articles fetched for GasTransmission/ Marketing: 0
# Fetching articles for category: LPG/ CNG/ PNG/ LNG Supplier
# Number of articles fetched for LPG/ CNG/ PNG/ LNG Supplier: 0
# Fetching articles for category: Trading - Gas
# Number of articles fetched for Trading - Gas: 5
# Fetching articles for category: Oil Exploration & Production
# Number of articles fetched for Oil Exploration & Production: 5
# Fetching articles for category: Offshore SupportSolution Drilling
# Number of articles fetched for Offshore SupportSolution Drilling: 0
# Fetching articles for category: Oil Storage & Transportation
# Number of articles fetched for Oil Storage & Transportation: 4
# Fetching articles for category: Oil Equipment & Services
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Refineries & Marketing
# Number of articles fetched for Refineries & Marketing: 1
# Fetching articles for category: Lubricants
# Number of articles fetched for Lubricants: 2
# Fetching articles for category: Coal
# Number of articles fetched for Coal: 5
# Fetching articles for category: Trading - Coal
# Number of articles fetched for Trading - Coal: 2
# Fetching articles for category: Edible Oil
# Number of articles fetched for Edible Oil: 0
# Fetching articles for category: Sugar
# Number of articles fetched for Sugar: 5
# Fetching articles for category: Tea & Coffee
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Other AgriculturalProducts
# Number of articles fetched for Other AgriculturalProducts: 0
# Fetching articles for category: Breweries & Distilleries
# Number of articles fetched for Breweries & Distilleries: 1
# Fetching articles for category: Other Beverages
# Number of articles fetched for Other Beverages: 5
# Fetching articles for category: Cigarettes & Tobacco Products
# Number of articles fetched for Cigarettes & Tobacco Products: 3
# Fetching articles for category: Animal Feed
# Number of articles fetched for Animal Feed: 3
# Fetching articles for category: Dairy Products
# Number of articles fetched for Dairy Products: 5
# Fetching articles for category: Other FoodProducts
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Packaged Foods
# Number of articles fetched for Packaged Foods: 1
# Fetching articles for category: Seafood
# Number of articles fetched for Seafood: 1
# Fetching articles for category: Meat Productsincluding Poultry
# Number of articles fetched for Meat Productsincluding Poultry: 0
# Fetching articles for category: Personal Care
# Number of articles fetched for Personal Care: 5
# Fetching articles for category: HouseholdProducts
# Number of articles fetched for HouseholdProducts: 0
# Fetching articles for category: Stationary
# Number of articles fetched for Stationary: 2
# Fetching articles for category: Diversified FMCG
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: FinancialInstitution
# Number of articles fetched for FinancialInstitution: 0
# Fetching articles for category: Housing FinanceCompany
# Number of articles fetched for Housing FinanceCompany: 0
# Fetching articles for category: InvestmentCompany
# Number of articles fetched for InvestmentCompany: 0
# Fetching articles for category: Non BankingFinancial Company(NBFC)
# Number of articles fetched for Non BankingFinancial Company(NBFC): 0
# Fetching articles for category: Other FinancialServices
# Number of articles fetched for Other FinancialServices: 0
# Fetching articles for category: Holding Company
# Number of articles fetched for Holding Company: 5
# Fetching articles for category: MicrofinanceInstitutions
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Securitisation
# Number of articles fetched for Securitisation: 0
# Fetching articles for category: Public Sector Bank
# Number of articles fetched for Public Sector Bank: 5
# Fetching articles for category: Private Sector Bank
# Number of articles fetched for Private Sector Bank: 5
# Fetching articles for category: Other Bank
# Number of articles fetched for Other Bank: 5
# Fetching articles for category: Asset ManagementCompany
# Number of articles fetched for Asset ManagementCompany: 0
# Fetching articles for category: Depositories,Clearing Housesand OtherIntermediaries
# Number of articles fetched for Depositories,Clearing Housesand OtherIntermediaries: 0
# Fetching articles for category: Financial ProductsDistributor
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Ratings
# Number of articles fetched for Ratings: 5
# Fetching articles for category: Exchange and DataPlatform
# Number of articles fetched for Exchange and DataPlatform: 0
# Fetching articles for category: Stockbroking & Allied
# Number of articles fetched for Stockbroking & Allied: 0
# Fetching articles for category: Other CapitalMarket relatedServices
# Number of articles fetched for Other CapitalMarket relatedServices: 0
# Fetching articles for category: General Insurance
# Number of articles fetched for General Insurance: 5
# Fetching articles for category: Life Insurance
# Number of articles fetched for Life Insurance: 5
# Fetching articles for category: Other InsuranceCompanies
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: InsuranceDistributors
# Number of articles fetched for InsuranceDistributors: 0
# Fetching articles for category: FinancialTechnology(Fintech)
# Number of articles fetched for FinancialTechnology(Fintech): 0
# Fetching articles for category: Pharmaceuticals
# Number of articles fetched for Pharmaceuticals: 5
# Fetching articles for category: Biotechnology
# Number of articles fetched for Biotechnology: 3
# Fetching articles for category: Medical Equipment& Supplies
# Number of articles fetched for Medical Equipment& Supplies: 5
# Fetching articles for category: Hospital
# Number of articles fetched for Hospital: 5
# Fetching articles for category: Healthcare ServiceProvider
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: HealthcareResearch, Analytics& Technology
# Number of articles fetched for HealthcareResearch, Analytics& Technology: 0
# Fetching articles for category: Civil Construction
# Number of articles fetched for Civil Construction: 5
# Fetching articles for category: Aerospace & Defense
# Number of articles fetched for Aerospace & Defense: 5
# Fetching articles for category: Tractors
# Number of articles fetched for Tractors: 2
# Fetching articles for category: CommercialVehicles
# Number of articles fetched for CommercialVehicles: 0
# Fetching articles for category: ConstructionVehicles
# Number of articles fetched for ConstructionVehicles: 0
# Fetching articles for category: Dealers–CommercialVehicles, Tractors,
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Heavy ElectricalEquipment
# Number of articles fetched for Heavy ElectricalEquipment: 0
# Fetching articles for category: Other ElectricalEquipment
# Number of articles fetched for Other ElectricalEquipment: 0
# Fetching articles for category: Railway Wagons
# Number of articles fetched for Railway Wagons: 0
# Fetching articles for category: Ship Building & Allied Services
# Number of articles fetched for Ship Building & Allied Services: 0
# Fetching articles for category: Industrial Products
# Number of articles fetched for Industrial Products: 5
# Fetching articles for category: Cables - Electricals
# Number of articles fetched for Cables - Electricals: 0
# Fetching articles for category: Castings & Forgings
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Packaging
# Number of articles fetched for Packaging: 5
# Fetching articles for category: Plastic Products -Industrial
# Number of articles fetched for Plastic Products -Industrial: 2
# Fetching articles for category: Rubber
# Number of articles fetched for Rubber: 2
# Fetching articles for category: Other IndustrialProducts
# Number of articles fetched for Other IndustrialProducts: 0
# Fetching articles for category: Glass - Industrial
# Number of articles fetched for Glass - Industrial: 2
# Fetching articles for category: Aluminium, Copper& Zinc Products
# Number of articles fetched for Aluminium, Copper& Zinc Products: 1
# Fetching articles for category: Iron & SteelProducts
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Abrasives & Bearings
# Number of articles fetched for Abrasives & Bearings: 0
# Fetching articles for category: Compressors,Pumps & DieselEngines
# Number of articles fetched for Compressors,Pumps & DieselEngines: 0
# Fetching articles for category: Electrodes & Refractories
# Number of articles fetched for Electrodes & Refractories: 0
# Fetching articles for category: Computers -Software & Consulting
# Number of articles fetched for Computers -Software & Consulting: 4
# Fetching articles for category: Software Products
# Number of articles fetched for Software Products: 5
# Fetching articles for category: IT Enabled Services
# Number of articles fetched for IT Enabled Services: 5
# Fetching articles for category: ComputersHardware & Equipments
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Dredging
# Number of articles fetched for Dredging: 0
# Fetching articles for category: Airline
# Number of articles fetched for Airline: 5
# Fetching articles for category: Logistics SolutionProvider
# Number of articles fetched for Logistics SolutionProvider: 0
# Fetching articles for category: Railways
# Number of articles fetched for Railways: 5
# Fetching articles for category: Road Transport
# Number of articles fetched for Road Transport: 3
# Fetching articles for category: Shipping
# Number of articles fetched for Shipping: 5
# Fetching articles for category: Transport RelatedServices
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Airport & Airportservices
# Number of articles fetched for Airport & Airportservices: 5
# Fetching articles for category: Port & Portservices
# Number of articles fetched for Port & Portservices: 5
# Fetching articles for category: Road Assets–Toll,Annuity, Hybrid-Annuity
# Number of articles fetched for Road Assets–Toll,Annuity, Hybrid-Annuity: 0
# Fetching articles for category: Trading & Distributors
# Number of articles fetched for Trading & Distributors: 5
# Fetching articles for category: Consulting Services
# Number of articles fetched for Consulting Services: 5
# Fetching articles for category: Data ProcessingServices
# Number of articles fetched for Data ProcessingServices: 0
# Fetching articles for category: DiversifiedCommercialServices
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Business ProcessOutsourcing (BPO)/ Knowledge ProcessOutsourcing (KPO)
# Number of articles fetched for Business ProcessOutsourcing (BPO)/ Knowledge ProcessOutsourcing (KPO): 0
# Fetching articles for category: Urban Local Bodies
# Number of articles fetched for Urban Local Bodies: 0
# Fetching articles for category: DevelopmentAuthority
# Number of articles fetched for DevelopmentAuthority: 0
# Fetching articles for category: Telecom - Cellular& Fixed lineservices
# Number of articles fetched for Telecom - Cellular& Fixed lineservices: 2
# Fetching articles for category: Telecom -Infrastructure
# Number of articles fetched for Telecom -Infrastructure: 5
# Fetching articles for category: Other TelecomServices
# Number of articles fetched for Other TelecomServices: 0
# Fetching articles for category: Telecom -Equipment & Accessories
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Power Trading
# Number of articles fetched for Power Trading: 5
# Fetching articles for category: Power -Transmission
# Number of articles fetched for Power -Transmission: 5
# Fetching articles for category: Power Generation
# Number of articles fetched for Power Generation: 5
# Fetching articles for category: Integrated PowerUtilities
# Number of articles fetched for Integrated PowerUtilities: 0
# Fetching articles for category: Power Distribution
# Number of articles fetched for Power Distribution: 5
# Fetching articles for category: Water Supply & Management
# Number of articles fetched for Water Supply & Management: 5
# Fetching articles for category: WasteManagement
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: EmergencyServices
# Number of articles fetched for EmergencyServices: 0
# Fetching articles for category: Multi Utilities
# Number of articles fetched for Multi Utilities: 0
# Fetching articles for category: Other Utilities
# Number of articles fetched for Other Utilities: 5
# Fetching articles for category: Diversified
# Number of articles fetched for Diversified: 5

# %%
category_list = [
    'Market Updates',
    'Earnings Reports',
    'Company News',
    'Sector News',
    'IPOs and Offerings',
    'Market Analysis',
    'Global Markets',
    'Economic Indicators',
    'Commodities and Forex',
    'Regulatory News',
    'Market Volatility',
    'Corporate Governance',
    'Technical Analysis',
    'Investment Strategies',
    'Personal Finance',
    'Market Sentiment',
    'Market Events',
    'Dividends and Buybacks',
    'Market Innovations',
    'Market Regulations',
    'Market Psychology',
    'Market Education',
    'Market Trends',
    'Market Disruptions',
    'Market Ethics',
    'Market Performance Metrics',
    'Market Research',
    'Market Outlook',
    'Market Technology',
    'Market Commentary',
    'Market Sentiment Indicators',
    'Market Performance by Geography',
    'Market Events Calendar',
    'Market Risk Management',
    'Market Insider Trading',
    'Market Investment Vehicles',
    'Market Quantitative Analysis',
    'Market Behavioral Finance',
    'Market Performance Benchmarks',
    'Market Crowdfunding and Crowdsourcing',
    'Market Philanthropy and Impact Investing',
    'Market Alternative Investments',
    'Market Data Analytics',
    'Market Behavioral Economics',
    'Government Budget and Fiscal Policy',
    'Monetary Policy and Central Banks',
    'Government Regulations and Policies',
    'Trade Policies and Tariffs',
    'Geopolitical Events and Risks',
    'Environmental, Social, and Governance (ESG) Investing',
    'Climate Change and Market Impacts',
    'Healthcare Policies and Regulations',
    'Education and Training',
    'Labor Market and Employment Trends',
    'Emerging Technologies and Innovation',
    'Cybersecurity and Data Privacy',
    'Infrastructure Development and Investments',
    'Energy Policies and Renewable Energy',
    'Consumer Trends and Behavior'
]

# Define the pre-defined categories for investors and politicians
categories = {category: [category] for category in category_list}

news_df = fetch_news_data()
# Out:
# Fetching articles for category: Market Updates
# Number of articles fetched for Market Updates: 5
# Fetching articles for category: Earnings Reports
# Number of articles fetched for Earnings Reports: 5
# Fetching articles for category: Company News
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Sector News
# Number of articles fetched for Sector News: 5
# Fetching articles for category: IPOs and Offerings
# Number of articles fetched for IPOs and Offerings: 4
# Fetching articles for category: Market Analysis
# Number of articles fetched for Market Analysis: 5
# Fetching articles for category: Global Markets
# Number of articles fetched for Global Markets: 5
# Fetching articles for category: Economic Indicators
# Number of articles fetched for Economic Indicators: 5
# Fetching articles for category: Commodities and Forex
# Number of articles fetched for Commodities and Forex: 0
# Fetching articles for category: Regulatory News
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Market Volatility
# Number of articles fetched for Market Volatility: 5
# Fetching articles for category: Corporate Governance
# Number of articles fetched for Corporate Governance: 5
# Fetching articles for category: Technical Analysis
# Number of articles fetched for Technical Analysis: 5
# Fetching articles for category: Investment Strategies
# Number of articles fetched for Investment Strategies: 5
# Fetching articles for category: Personal Finance
# Number of articles fetched for Personal Finance: 5
# Fetching articles for category: Market Sentiment
# Number of articles fetched for Market Sentiment: 5
# Fetching articles for category: Market Events
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Dividends and Buybacks
# Number of articles fetched for Dividends and Buybacks: 3
# Fetching articles for category: Market Innovations
# Number of articles fetched for Market Innovations: 5
# Fetching articles for category: Market Regulations
# Number of articles fetched for Market Regulations: 5
# Fetching articles for category: Market Psychology
# Number of articles fetched for Market Psychology: 0
# Fetching articles for category: Market Education
# Number of articles fetched for Market Education: 5
# Fetching articles for category: Market Trends
# Number of articles fetched for Market Trends: 5
# Fetching articles for category: Market Disruptions
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Market Ethics
# Number of articles fetched for Market Ethics: 0
# Fetching articles for category: Market Performance Metrics
# Number of articles fetched for Market Performance Metrics: 5
# Fetching articles for category: Market Research
# Number of articles fetched for Market Research: 5
# Fetching articles for category: Market Outlook
# Number of articles fetched for Market Outlook: 5
# Fetching articles for category: Market Technology
# Number of articles fetched for Market Technology: 5
# Fetching articles for category: Market Commentary
# Number of articles fetched for Market Commentary: 5
# Fetching articles for category: Market Sentiment Indicators
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Market Performance by Geography
# Number of articles fetched for Market Performance by Geography: 4
# Fetching articles for category: Market Events Calendar
# Number of articles fetched for Market Events Calendar: 3
# Fetching articles for category: Market Risk Management
# Number of articles fetched for Market Risk Management: 5
# Fetching articles for category: Market Insider Trading
# Number of articles fetched for Market Insider Trading: 4
# Fetching articles for category: Market Investment Vehicles
# Number of articles fetched for Market Investment Vehicles: 5
# Fetching articles for category: Market Quantitative Analysis
# Number of articles fetched for Market Quantitative Analysis: 5
# Fetching articles for category: Market Behavioral Finance
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Market Performance Benchmarks
# Number of articles fetched for Market Performance Benchmarks: 0
# Fetching articles for category: Market Crowdfunding and Crowdsourcing
# Number of articles fetched for Market Crowdfunding and Crowdsourcing: 0
# Fetching articles for category: Market Philanthropy and Impact Investing
# Number of articles fetched for Market Philanthropy and Impact Investing: 0
# Fetching articles for category: Market Alternative Investments
# Number of articles fetched for Market Alternative Investments: 5
# Fetching articles for category: Market Data Analytics
# Number of articles fetched for Market Data Analytics: 5
# Fetching articles for category: Market Behavioral Economics
# Number of articles fetched for Market Behavioral Economics: 0
# Fetching articles for category: Government Budget and Fiscal Policy
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Monetary Policy and Central Banks
# Number of articles fetched for Monetary Policy and Central Banks: 3
# Fetching articles for category: Government Regulations and Policies
# Number of articles fetched for Government Regulations and Policies: 4
# Fetching articles for category: Trade Policies and Tariffs
# Number of articles fetched for Trade Policies and Tariffs: 1
# Fetching articles for category: Geopolitical Events and Risks
# Number of articles fetched for Geopolitical Events and Risks: 0
# Fetching articles for category: Environmental, Social, and Governance (ESG) Investing
# Number of articles fetched for Environmental, Social, and Governance (ESG) Investing: 0
# Fetching articles for category: Climate Change and Market Impacts
# Number of articles fetched for Climate Change and Market Impacts: 1
# Fetching articles for category: Healthcare Policies and Regulations
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: Education and Training
# Number of articles fetched for Education and Training: 5
# Fetching articles for category: Labor Market and Employment Trends
# Number of articles fetched for Labor Market and Employment Trends: 2
# Fetching articles for category: Emerging Technologies and Innovation
# Number of articles fetched for Emerging Technologies and Innovation: 5
# Fetching articles for category: Cybersecurity and Data Privacy
# Number of articles fetched for Cybersecurity and Data Privacy: 1
# Fetching articles for category: Infrastructure Development and Investments
# Number of articles fetched for Infrastructure Development and Investments: 5
# Fetching articles for category: Energy Policies and Renewable Energy
# Number of articles fetched for Energy Policies and Renewable Energy: 3
# Fetching articles for category: Consumer Trends and Behavior
# API Rate Limit Exceeded. Trying with another API key...

# %%
news_df
# Out:
#                                        Category  \
# 0                                Market Updates
# 1                                Market Updates
# 2                                Market Updates
# 3                                Market Updates
# 4                                Market Updates
# ..                                          ...
# 173  Infrastructure Development and Investments
# 174  Infrastructure Development and Investments
# 175        Energy Policies and Renewable Energy
# 176        Energy Policies and Renewable Energy
# 177        Energy Policies and Renewable Energy
#
#                                          News Headline Sentiment
# 0    Shaitaan Opening Day Box Office: Ajay Devgn’s ...   Neutral
# 1    In Vitro Diagnostics Market Size Worth USD 128...  Positive
# 2    Copper Fees Plunge Close to Zero in Test For C...   Neutral
# 3    Global tech firms likely to lead India’s local...   Neutral
# 4    Govt keeps interest rates on small savings sch...  Negative
# ..                                                 ...       ...
# 173  Cold Chain Logistics Market Size to Grow USD 8...  Negative
# 174  Global Carbon Steel Market to Reach $1,284.51 ...  Positive
# 175  Green Hydrogen Market Analysis to 2033: Solar ...   Neutral
# 176  Concentrated Solar Power Market to Reach $12.0...  Positive
# 177  A Technocratic War on Farmers, Oil Dependency,...   Neutral
#
# [178 rows x 3 columns]

# %%
unique_sectors = def_df["Sector"].unique()

# Iterate through merged_news_df to add Sector
sectors = []
for index, row in merged_news_df.iterrows():
    headline = row['News Headline']
    sector = None
    
    # Find similar sector using fuzzy matching
    similar_sector = find_similar_sector_or_industry(headline, unique_sectors)
    if similar_sector:
        sector = similar_sector
    
    sectors.append(sector)

merged_news_df['Sector'] = sectors

# %%
final_news_df = pd.merge(merged_news_df, stock_df[["Ticker", "Name"]], on="Ticker", how="left")
# Save the final dataframe to CSV
final_news_df.to_csv(r"C:\Users\DELL\Desktop\Projects\LOC 6.0\Final News DataFrame\General DataFrame.csv", index=False)

# %%
import pandas as pd
import requests
from textblob import TextBlob
from dotenv import load_dotenv
from collections import Counter

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# Load API keys from environment variable or any other source
api_keys = ["c016e6eeff684982bcfdef26b326c2b7", "5c8422ca2b604f4481e4a43aa95bb074", "cc7baa3c527f4624873dc8f237b2df5e", "060a295073e94514a268c437f2d0fc64", "67a4bf1c0713482fb55ad691623aab49", "a40ac68e681949d28f84e7152cb56d64", "c223bf69c1d24884ad47c00ffe4b4edc"]
current_key_index = 0

def get_api_key():
    global current_key_index
    api_key = api_keys[current_key_index]
    current_key_index = (current_key_index + 1) % len(api_keys)
    return api_key

# Load dataframes
stock_df = pd.read_csv("Stock_DataFrame.csv")
def_df = pd.read_csv("Sector_Definitions.csv")

# Extract prominent keywords from definitions
def extract_keywords(text):
    doc = nlp(text)
    tokens = [token.text.lower() for token in doc if token.pos_ in ['NOUN', 'PROPN'] and not token.is_stop]
    return tokens

all_keywords = []
for definition in def_df['Definition']:
    keywords = extract_keywords(definition)
    all_keywords.extend(keywords)

# Get the most common keywords as categories
category_count = Counter(all_keywords)
categories = [category for category, count in category_count.most_common()]

# Function to fetch news data for a specific category
def fetch_news_data(category):
    news_data = []
    print(f"Fetching articles for category: {category}")
    url = f"https://newsapi.org/v2/everything?q=India+{category}&from=2024-03-08&to=2024-03-09&sortBy=publishedAt&apiKey={get_api_key()}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        articles = data["articles"][:5]  # Limit to 5 articles per category
        print(f"Number of articles fetched for {category}: {len(articles)}")
        for article in articles:
            news_data.append({
                "Category": category,
                "News Headline": article["title"],
                "Sentiment": get_sentiment(article["title"])
            })
    elif response.status_code == 429:  # Rate Limit Exceeded
        print("API Rate Limit Exceeded. Trying with another API key...")
    else:
        print(f"Failed to fetch articles for {category}. Status code: {response.status_code}")
    return pd.DataFrame(news_data)

# Function to perform sentiment analysis
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity == 0:
        return "Neutral"
    else:
        return "Negative"

# Fetch news data for each category
news_data = pd.DataFrame()
for category in categories:
    news_data = pd.concat([news_data, fetch_news_data(category)], ignore_index=True)

news_data
# Out:
# Fetching articles for category: companies
# Number of articles fetched for companies: 5
# Fetching articles for category: manufacturers
# Number of articles fetched for manufacturers: 5
# Fetching articles for category: distributors
# Number of articles fetched for distributors: 5
# Fetching articles for category: products
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: services
# Number of articles fetched for services: 5
# Fetching articles for category: distributor
# Number of articles fetched for distributor: 4
# Fetching articles for category: consumer
# Number of articles fetched for consumer: 5
# Fetching articles for category: distribution
# Number of articles fetched for distribution: 5
# Fetching articles for category: trading
# Number of articles fetched for trading: 5
# Fetching articles for category: operators
# Number of articles fetched for operators: 5
# Fetching articles for category: owners
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: construction
# Number of articles fetched for construction: 5
# Fetching articles for category: trusts
# Number of articles fetched for trusts: 5
# Fetching articles for category: equipment
# Number of articles fetched for equipment: 5
# Fetching articles for category: producers
# Number of articles fetched for producers: 5
# Fetching articles for category: equipments
# Number of articles fetched for equipments: 0
# Fetching articles for category: discretionary
# Number of articles fetched for discretionary: 5
# Fetching articles for category: investment
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: revenue
# Number of articles fetched for revenue: 5
# Fetching articles for category: power
# Number of articles fetched for power: 5
# Fetching articles for category: insurance
# Number of articles fetched for insurance: 5
# Fetching articles for category: telecom
# Number of articles fetched for telecom: 5
# Fetching articles for category: manufacturing
# Number of articles fetched for manufacturing: 5
# Fetching articles for category: vehicles
# Number of articles fetched for vehicles: 5
# Fetching articles for category: excludes
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: service
# Number of articles fetched for service: 5
# Fetching articles for category: development
# Number of articles fetched for development: 5
# Fetching articles for category: bank
# Number of articles fetched for bank: 5
# Fetching articles for category: %
# Number of articles fetched for %: 5
# Fetching articles for category: banks
# Number of articles fetched for banks: 5
# Fetching articles for category: manufacturer
# Number of articles fetched for manufacturer: 5
# Fetching articles for category: supplier
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: accessories
# Number of articles fetched for accessories: 5
# Fetching articles for category: plastic
# Number of articles fetched for plastic: 5
# Fetching articles for category: segment
# Number of articles fetched for segment: 5
# Fetching articles for category: data
# Number of articles fetched for data: 5
# Fetching articles for category: provision
# Number of articles fetched for provision: 5
# Fetching articles for category: oil
# Number of articles fetched for oil: 5
# Fetching articles for category: chemicals
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: mining
# Number of articles fetched for mining: 5
# Fetching articles for category: passenger
# Number of articles fetched for passenger: 5
# Fetching articles for category: auto
# Number of articles fetched for auto: 5
# Fetching articles for category: components
# Number of articles fetched for components: 5
# Fetching articles for category: food
# Number of articles fetched for food: 5
# Fetching articles for category: medium
# Number of articles fetched for medium: 5
# Fetching articles for category: production
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: estate
# Number of articles fetched for estate: 5
# Fetching articles for category: transportation
# Number of articles fetched for transportation: 5
# Fetching articles for category: business
# Number of articles fetched for business: 5
# Fetching articles for category: india
# Number of articles fetched for india: 5
# Fetching articles for category: iron
# Number of articles fetched for iron: 5
# Fetching articles for category: processing
# Number of articles fetched for processing: 5
# Fetching articles for category: metals
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: coal
# Number of articles fetched for coal: 5
# Fetching articles for category: automobiles
# Number of articles fetched for automobiles: 4
# Fetching articles for category: gas
# Number of articles fetched for gas: 5
# Fetching articles for category: rubber
# Number of articles fetched for rubber: 2
# Fetching articles for category: electronics
# Number of articles fetched for electronics: 5
# Fetching articles for category: processors
# Number of articles fetched for processors: 2
# Fetching articles for category: yarn
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: marketing
# Number of articles fetched for marketing: 5
# Fetching articles for category: platform
# Number of articles fetched for platform: 5
# Fetching articles for category: tv
# Number of articles fetched for tv: 5
# Fetching articles for category: management
# Number of articles fetched for management: 5
# Fetching articles for category: education
# Number of articles fetched for education: 5
# Fetching articles for category: reserve
# Number of articles fetched for reserve: 5
# Fetching articles for category: rbi
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: securities
# Number of articles fetched for securities: 5
# Fetching articles for category: sector
# Number of articles fetched for sector: 5
# Fetching articles for category: transmission
# Number of articles fetched for transmission: 5
# Fetching articles for category: system
# Number of articles fetched for system: 5
# Fetching articles for category: segments
# Number of articles fetched for segments: 5
# Fetching articles for category: producer
# Number of articles fetched for producer: 5
# Fetching articles for category: industry
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: aluminium
# Number of articles fetched for aluminium: 5
# Fetching articles for category: materials
# Number of articles fetched for materials: 5
# Fetching articles for category: paper
# Number of articles fetched for paper: 5
# Fetching articles for category: home
# Number of articles fetched for home: 5
# Fetching articles for category: batteries
# Number of articles fetched for batteries: 5
# Fetching articles for category: automobile
# Number of articles fetched for automobile: 5
# Fetching articles for category: video
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: goods
# Number of articles fetched for goods: 5
# Fetching articles for category: glass
# Number of articles fetched for glass: 5
# Fetching articles for category: household
# Number of articles fetched for household: 5
# Fetching articles for category: manufacturer/
# Number of articles fetched for manufacturer/: 5
# Fetching articles for category: providers
# Number of articles fetched for providers: 5
# Fetching articles for category: engines
# Number of articles fetched for engines: 5
# Fetching articles for category: -
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: merchandise
# Number of articles fetched for merchandise: 5
# Fetching articles for category: internet
# Number of articles fetched for internet: 5
# Fetching articles for category: movies
# Number of articles fetched for movies: 5
# Fetching articles for category: analytics
# Number of articles fetched for analytics: 5
# Fetching articles for category: facilities
# Number of articles fetched for facilities: 5
# Fetching articles for category: financial
# Number of articles fetched for financial: 5
# Fetching articles for category: capital
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: funds
# Number of articles fetched for funds: 5
# Fetching articles for category: hospitals
# Number of articles fetched for hospitals: 5
# Fetching articles for category: bridges
# Number of articles fetched for bridges: 4
# Fetching articles for category: engineering
# Number of articles fetched for engineering: 5
# Fetching articles for category: manufactures
# Number of articles fetched for manufactures: 5
# Fetching articles for category: cargo
# Number of articles fetched for cargo: 5
# Fetching articles for category: fibres
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: explosives
# Number of articles fetched for explosives: 3
# Fetching articles for category: dyes
# Number of articles fetched for dyes: 1
# Fetching articles for category: pigments
# Number of articles fetched for pigments: 0
# Fetching articles for category: propylene
# Number of articles fetched for propylene: 0
# Fetching articles for category: printing
# Number of articles fetched for printing: 5
# Fetching articles for category: material
# Number of articles fetched for material: 5
# Fetching articles for category: gases
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: cement
# Number of articles fetched for cement: 5
# Fetching articles for category: granites
# Number of articles fetched for granites: 0
# Fetching articles for category: marbles
# Number of articles fetched for marbles: 0
# Fetching articles for category: ferro
# Number of articles fetched for ferro: 0
# Fetching articles for category: steel
# Number of articles fetched for steel: 5
# Fetching articles for category: copper
# Number of articles fetched for copper: 5
# Fetching articles for category: zinc
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: gold
# Number of articles fetched for gold: 5
# Fetching articles for category: energy
# Number of articles fetched for energy: 5
# Fetching articles for category: timber
# Number of articles fetched for timber: 0
# Fetching articles for category: plywood
# Number of articles fetched for plywood: 0
# Fetching articles for category: laminates
# Number of articles fetched for laminates: 1
# Fetching articles for category: furniture
# Number of articles fetched for furniture: 5
# Fetching articles for category: jute
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: wheelers
# Number of articles fetched for wheelers: 1
# Fetching articles for category: bicycles
# Number of articles fetched for bicycles: 1
# Fetching articles for category: tricycles
# Number of articles fetched for tricycles: 0
# Fetching articles for category: tyres
# Number of articles fetched for tyres: 1
# Fetching articles for category: television
# Number of articles fetched for television: 5
# Fetching articles for category: appliances
# Number of articles fetched for appliances: 3
# Fetching articles for category: leather
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: bags
# Number of articles fetched for bags: 5
# Fetching articles for category: types
# Number of articles fetched for types: 5
# Fetching articles for category: footwear
# Number of articles fetched for footwear: 1
# Fetching articles for category: sports
# Number of articles fetched for sports: 5
# Fetching articles for category: games
# Number of articles fetched for games: 5
# Fetching articles for category: garments
# Number of articles fetched for garments: 0
# Fetching articles for category: apparels
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: publisher
# Number of articles fetched for publisher: 5
# Fetching articles for category: newspapers
# Number of articles fetched for newspapers: 1
# Fetching articles for category: magazines
# Number of articles fetched for magazines: 3
# Fetching articles for category: periodicals
# Number of articles fetched for periodicals: 0
# Fetching articles for category: e
# Number of articles fetched for e: 5
# Fetching articles for category: directory
# Number of articles fetched for directory: 2
# Fetching articles for category: suppliers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: buyers
# Number of articles fetched for buyers: 5
# Fetching articles for category: entertainment
# Number of articles fetched for entertainment: 5
# Fetching articles for category: shows
# Number of articles fetched for shows: 5
# Fetching articles for category: commercial
# Number of articles fetched for commercial: 5
# Fetching articles for category: shops
# Number of articles fetched for shops: 5
# Fetching articles for category: properties
# Number of articles fetched for properties: 5
# Fetching articles for category: agents
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: leasing
# Number of articles fetched for leasing: 4
# Fetching articles for category: hotels
# Number of articles fetched for hotels: 5
# Fetching articles for category: resorts
# Number of articles fetched for resorts: 5
# Fetching articles for category: recreation
# Number of articles fetched for recreation: 3
# Fetching articles for category: coffee
# Number of articles fetched for coffee: 5
# Fetching articles for category: tour
# Number of articles fetched for tour: 5
# Fetching articles for category: stream
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: training
# Number of articles fetched for training: 5
# Fetching articles for category: classroom
# Number of articles fetched for classroom: 0
# Fetching articles for category: storage
# Number of articles fetched for storage: 5
# Fetching articles for category: facility
# Number of articles fetched for facility: 5
# Fetching articles for category: security
# Number of articles fetched for security: 5
# Fetching articles for category: stationary
# Number of articles fetched for stationary: 2
# Fetching articles for category: health
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: stores
# Number of articles fetched for stores: 5
# Fetching articles for category: and/
# Number of articles fetched for and/: 5
# Fetching articles for category: exploration
# Number of articles fetched for exploration: 5
# Fetching articles for category: coke
# Number of articles fetched for coke: 0
# Fetching articles for category: beverages
# Number of articles fetched for beverages: 5
# Fetching articles for category: institutions
# Number of articles fetched for institutions: 5
# Fetching articles for category: income
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: banking
# Number of articles fetched for banking: 5
# Fetching articles for category: company
# Number of articles fetched for company: 5
# Fetching articles for category: microfinance
# Number of articles fetched for microfinance: 2
# Fetching articles for category: payment
# Number of articles fetched for payment: 5
# Fetching articles for category: activities
# Number of articles fetched for activities: 5
# Fetching articles for category: end
# Number of articles fetched for end: 5
# Fetching articles for category: brokerage
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: life
# Number of articles fetched for life: 5
# Fetching articles for category: line
# Number of articles fetched for line: 5
# Fetching articles for category: pharmaceuticals
# Number of articles fetched for pharmaceuticals: 5
# Fetching articles for category: research
# Number of articles fetched for research: 5
# Fetching articles for category: x
# Number of articles fetched for x: 5
# Fetching articles for category: ray
# Number of articles fetched for ray: 5
# Fetching articles for category: mri
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: roads
# Number of articles fetched for roads: 5
# Fetching articles for category: defense
# Number of articles fetched for defense: 5
# Fetching articles for category: tractors
# Number of articles fetched for tractors: 3
# Fetching articles for category: machinery
# Number of articles fetched for machinery: 5
# Fetching articles for category: control
# Number of articles fetched for control: 5
# Fetching articles for category: fire
# Number of articles fetched for fire: 5
# Fetching articles for category: alarm
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: door
# Number of articles fetched for door: 5
# Fetching articles for category: phones
# Number of articles fetched for phones: 5
# Fetching articles for category: cables
# Number of articles fetched for cables: 4
# Fetching articles for category: bearings
# Number of articles fetched for bearings: 2
# Fetching articles for category: software
# Number of articles fetched for software: 5
# Fetching articles for category: consulting
# Number of articles fetched for consulting: 5
# Fetching articles for category: infrastructure
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: marine
# Number of articles fetched for marine: 5
# Fetching articles for category: process
# Number of articles fetched for process: 5
# Fetching articles for category: outsourcing
# Number of articles fetched for outsourcing: 4
# Fetching articles for category: instruments
# Number of articles fetched for instruments: 5
# Fetching articles for category: electricity
# Number of articles fetched for electricity: 5
# Fetching articles for category: generation
# Number of articles fetched for generation: 5
# Fetching articles for category: utilities
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: films
# Number of articles fetched for films: 5
# Fetching articles for category: manufacture
# Number of articles fetched for manufacture: 5
# Fetching articles for category: variety
# Number of articles fetched for variety: 5
# Fetching articles for category: additives
# Number of articles fetched for additives: 5
# Fetching articles for category: polymers
# Number of articles fetched for polymers: 1
# Fetching articles for category: adhesives
# Number of articles fetched for adhesives: 1
# Fetching articles for category: sealants
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: coatings
# Number of articles fetched for coatings: 3
# Fetching articles for category: carbon
# Number of articles fetched for carbon: 5
# Fetching articles for category: black
# Number of articles fetched for black: 5
# Fetching articles for category: exporter
# Number of articles fetched for exporter: 5
# Fetching articles for category: petrochemical
# Number of articles fetched for petrochemical: 0
# Fetching articles for category: oxide
# Number of articles fetched for oxide: 3
# Fetching articles for category: glycols
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: polyols
# Number of articles fetched for polyols: 0
# Fetching articles for category: nylon
# Number of articles fetched for nylon: 0
# Fetching articles for category: polyester
# Number of articles fetched for polyester: 1
# Fetching articles for category: acrylic
# Number of articles fetched for acrylic: 3
# Fetching articles for category: plastics
# Number of articles fetched for plastics: 3
# Fetching articles for category: industrial
# Number of articles fetched for industrial: 5
# Fetching articles for category: fertilizers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: agrochemicals
# Number of articles fetched for agrochemicals: 0
# Fetching articles for category: pesticides
# Number of articles fetched for pesticides: 5
# Fetching articles for category: sand
# Number of articles fetched for sand: 5
# Fetching articles for category: silico
# Number of articles fetched for silico: 0
# Fetching articles for category: manganese
# Number of articles fetched for manganese: 0
# Fetching articles for category: alloys
# Number of articles fetched for alloys: 0
# Fetching articles for category: briquette
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: ash
# Number of articles fetched for ash: 2
# Fetching articles for category: bricks
# Number of articles fetched for bricks: 1
# Fetching articles for category: pig
# Number of articles fetched for pig: 1
# Fetching articles for category: sponge
# Number of articles fetched for sponge: 0
# Fetching articles for category: silver
# Number of articles fetched for silver: 5
# Fetching articles for category: platinum
# Number of articles fetched for platinum: 2
# Fetching articles for category: minerals
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: boards
# Number of articles fetched for boards: 5
# Fetching articles for category: wood
# Number of articles fetched for wood: 5
# Fetching articles for category: soil
# Number of articles fetched for soil: 5
# Fetching articles for category: pulp
# Number of articles fetched for pulp: 3
# Fetching articles for category: firewood
# Number of articles fetched for firewood: 3
# Fetching articles for category: cork
# Number of articles fetched for cork: 1
# Fetching articles for category: shellac
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: cross
# Number of articles fetched for cross: 5
# Fetching articles for category: laminated
# Number of articles fetched for laminated: 0
# Fetching articles for category: furnishing
# Number of articles fetched for furnishing: 0
# Fetching articles for category: /utility
# Number of articles fetched for /utility: 5
# Fetching articles for category: car
# Number of articles fetched for car: 5
# Fetching articles for category: bus
# Number of articles fetched for bus: 5
# Fetching articles for category: taxis
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: rickshaws
# Number of articles fetched for rickshaws: 1
# Fetching articles for category: motorcycles
# Number of articles fetched for motorcycles: 0
# Fetching articles for category: scooters
# Number of articles fetched for scooters: 3
# Fetching articles for category: cars
# Number of articles fetched for cars: 5
# Fetching articles for category: utility
# Number of articles fetched for utility: 5
# Fetching articles for category: fasteners
# Number of articles fetched for fasteners: 0
# Fetching articles for category: cylinders
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: gems
# Number of articles fetched for gems: 4
# Fetching articles for category: jewellery
# Number of articles fetched for jewellery: 5
# Fetching articles for category: watches
# Number of articles fetched for watches: 5
# Fetching articles for category: luxury
# Number of articles fetched for luxury: 5
# Fetching articles for category: polishing
# Number of articles fetched for polishing: 2
# Fetching articles for category: diamonds
# Number of articles fetched for diamonds: 5
# Fetching articles for category: air
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: conditioners
# Number of articles fetched for conditioners: 1
# Fetching articles for category: juicers
# Number of articles fetched for juicers: 0
# Fetching articles for category: microwave
# Number of articles fetched for microwave: 1
# Fetching articles for category: ovens
# Number of articles fetched for ovens: 1
# Fetching articles for category: cutlery
# Number of articles fetched for cutlery: 0
# Fetching articles for category: utensils
# Number of articles fetched for utensils: 1
# Fetching articles for category: specialties
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: belt
# Number of articles fetched for belt: 4
# Fetching articles for category: leisure
# Number of articles fetched for leisure: 1
# Fetching articles for category: gift
# Number of articles fetched for gift: 5
# Fetching articles for category: articles
# Number of articles fetched for articles: 5
# Fetching articles for category: toys
# Number of articles fetched for toys: 1
# Fetching articles for category: households
# Number of articles fetched for households: 5
# Fetching articles for category: suitcase
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: briefcase
# Number of articles fetched for briefcase: 0
# Fetching articles for category: ware
# Number of articles fetched for ware: 1
# Fetching articles for category: plumbing
# Number of articles fetched for plumbing: 3
# Fetching articles for category: fixtures
# Number of articles fetched for fixtures: 1
# Fetching articles for category: sinks
# Number of articles fetched for sinks: 0
# Fetching articles for category: lavatories
# Number of articles fetched for lavatories: 0
# Fetching articles for category: toilet
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: bowls
# Number of articles fetched for bowls: 3
# Fetching articles for category: interior
# Number of articles fetched for interior: 5
# Fetching articles for category: paints
# Number of articles fetched for paints: 3
# Fetching articles for category: carpets
# Number of articles fetched for carpets: 1
# Fetching articles for category: curtains
# Number of articles fetched for curtains: 3
# Fetching articles for category: floor
# Number of articles fetched for floor: 5
# Fetching articles for category: wall
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: tiles
# Number of articles fetched for tiles: 2
# Fetching articles for category: knitwears
# Number of articles fetched for knitwears: 0
# Fetching articles for category: innerwears
# Number of articles fetched for innerwears: 0
# Fetching articles for category: textiles
# Number of articles fetched for textiles: 5
# Fetching articles for category: fabrics
# Number of articles fetched for fabrics: 1
# Fetching articles for category: silk
# Number of articles fetched for silk: 4
# Fetching articles for category: spinning
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: cotton
# Number of articles fetched for cotton: 5
# Fetching articles for category: operations
# Number of articles fetched for operations: 5
# Fetching articles for category: textile
# Number of articles fetched for textile: 5
# Fetching articles for category: advertising
# Number of articles fetched for advertising: 5
# Fetching articles for category: relations
# Number of articles fetched for relations: 5
# Fetching articles for category: billboard
# Number of articles fetched for billboard: 5
# Fetching articles for category: telemarketers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: media
# Number of articles fetched for media: 5
# Fetching articles for category: search
# Number of articles fetched for search: 5
# Fetching articles for category: platforms
# Number of articles fetched for platforms: 5
# Fetching articles for category: online
# Number of articles fetched for online: 5
# Fetching articles for category: shopping
# Number of articles fetched for shopping: 5
# Fetching articles for category: catalogue
# Number of articles fetched for catalogue: 4
# Fetching articles for category: retail
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: print
# Number of articles fetched for print: 5
# Fetching articles for category: theatres
# Number of articles fetched for theatres: 1
# Fetching articles for category: auditoriums
# Number of articles fetched for auditoriums: 0
# Fetching articles for category: contents
# Number of articles fetched for contents: 4
# Fetching articles for category: ott
# Number of articles fetched for ott: 3
# Fetching articles for category: screening
# Number of articles fetched for screening: 5
# Fetching articles for category: music
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: teams
# Number of articles fetched for teams: 5
# Fetching articles for category: film
# Number of articles fetched for film: 5
# Fetching articles for category: exhibition
# Number of articles fetched for exhibition: 5
# Fetching articles for category: channels
# Number of articles fetched for channels: 5
# Fetching articles for category: broadcasting
# Number of articles fetched for broadcasting: 2
# Fetching articles for category: cable
# Number of articles fetched for cable: 3
# Fetching articles for category: dth
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: publication
# Number of articles fetched for publication: 5
# Fetching articles for category: books
# Number of articles fetched for books: 5
# Fetching articles for category: documents
# Number of articles fetched for documents: 5
# Fetching articles for category: offices
# Number of articles fetched for offices: 5
# Fetching articles for category: ownership
# Number of articles fetched for ownership: 5
# Fetching articles for category: acquisition
# Number of articles fetched for acquisition: 5
# Fetching articles for category: operation
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: restaurants
# Number of articles fetched for restaurants: 5
# Fetching articles for category: clubs
# Number of articles fetched for clubs: 3
# Fetching articles for category: bars
# Number of articles fetched for bars: 5
# Fetching articles for category: fast-
# Number of articles fetched for fast-: 5
# Fetching articles for category: amusement
# Number of articles fetched for amusement: 1
# Fetching articles for category: parks
# Number of articles fetched for parks: 5
# Fetching articles for category: casinos
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: wellness
# Number of articles fetched for wellness: 5
# Fetching articles for category: gymnasium
# Number of articles fetched for gymnasium: 0
# Fetching articles for category: yoga
# Number of articles fetched for yoga: 5
# Fetching articles for category: centre
# Number of articles fetched for centre: 5
# Fetching articles for category: beauty
# Number of articles fetched for beauty: 5
# Fetching articles for category: parlours
# Number of articles fetched for parlours: 0
# Fetching articles for category: salons
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: ticketing
# Number of articles fetched for ticketing: 0
# Fetching articles for category: visa
# Number of articles fetched for visa: 5
# Fetching articles for category: hotel
# Number of articles fetched for hotel: 5
# Fetching articles for category: vehicle
# Number of articles fetched for vehicle: 5
# Fetching articles for category: booking
# Number of articles fetched for booking: 5
# Fetching articles for category: event
# Number of articles fetched for event: 5
# Fetching articles for category: managers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: housekeeping
# Number of articles fetched for housekeeping: 1
# Fetching articles for category: store
# Number of articles fetched for store: 5
# Fetching articles for category: class
# Number of articles fetched for class: 5
# Fetching articles for category: sale
# Number of articles fetched for sale: 5
# Fetching articles for category: pharmaceutical
# Number of articles fetched for pharmaceutical: 5
# Fetching articles for category: range
# Number of articles fetched for range: 5
# Fetching articles for category: product
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: categories
# Number of articles fetched for categories: 5
# Fetching articles for category: department
# Number of articles fetched for department: 5
# Fetching articles for category: wholesalers
# Number of articles fetched for wholesalers: 1
# Fetching articles for category: lpg
# Number of articles fetched for lpg: 5
# Fetching articles for category: cng
# Number of articles fetched for cng: 5
# Fetching articles for category: png
# Number of articles fetched for png: 3
# Fetching articles for category: lng
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: activity
# Number of articles fetched for activity: 5
# Fetching articles for category: drilling
# Number of articles fetched for drilling: 4
# Fetching articles for category: refining
# Number of articles fetched for refining: 5
# Fetching articles for category: petroleum
# Number of articles fetched for petroleum: 5
# Fetching articles for category: lubricants
# Number of articles fetched for lubricants: 2
# Fetching articles for category: lignite
# Number of articles fetched for lignite: 0
# Fetching articles for category: sugar
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: tea
# Number of articles fetched for tea: 5
# Fetching articles for category: distillers
# Number of articles fetched for distillers: 1
# Fetching articles for category: cigarettes
# Number of articles fetched for cigarettes: 3
# Fetching articles for category: tobacco
# Number of articles fetched for tobacco: 2
# Fetching articles for category: animal
# Number of articles fetched for animal: 5
# Fetching articles for category: feed
# Number of articles fetched for feed: 5
# Fetching articles for category: dairy
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: foods
# Number of articles fetched for foods: 5
# Fetching articles for category: biscuits
# Number of articles fetched for biscuits: 2
# Fetching articles for category: chocolates
# Number of articles fetched for chocolates: 1
# Fetching articles for category: chips
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: culture
# Number of articles fetched for culture: 5
# Fetching articles for category: fish
# Number of articles fetched for fish: 5
# Fetching articles for category: shrimp
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: sea/
# Number of articles fetched for sea/: 5
# Fetching articles for category: freshwater
# Number of articles fetched for freshwater: 2
# Fetching articles for category: meat
# Number of articles fetched for meat: 5
# Fetching articles for category: breeders
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: chicken
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: eggs
# Number of articles fetched for eggs: 5
# Fetching articles for category: toothpaste
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: shampoo
# Number of articles fetched for shampoo: 2
# Fetching articles for category: perfume
# Number of articles fetched for perfume: 0
# Fetching articles for category: cosmetics
# Number of articles fetched for cosmetics: 4
# Fetching articles for category: foils
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: detergents
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: matchstick
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: tissues
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: soaps
# Number of articles fetched for soaps: 0
# Fetching articles for category: pen
# Number of articles fetched for pen: 1
# Fetching articles for category: pencil
# Number of articles fetched for pencil: 0
# Fetching articles for category: notebooks
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: fmcg
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: section
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: 4(1
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: act
# Number of articles fetched for act: 5
# Fetching articles for category: loan
# Number of articles fetched for loan: 5
# Fetching articles for category: housing
# Number of articles fetched for housing: 5
# Fetching articles for category: interest
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: appreciation
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: investments
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: non
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: nbfc
# Number of articles fetched for nbfc: 5
# Fetching articles for category: holding
# Number of articles fetched for holding: 5
# Fetching articles for category: issue
# Number of articles fetched for issue: 5
# Fetching articles for category: certificates
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: asset
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: mortgage
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: assets
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: securitisation
# Number of articles fetched for securitisation: 0
# Fetching articles for category: transactions
# Number of articles fetched for transactions: 5
# Fetching articles for category: central
# Number of articles fetched for central: 5
# Fetching articles for category: state
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: government
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: public
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: private
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: fund
# Number of articles fetched for fund: 5
# Fetching articles for category: depository
# Number of articles fetched for depository: 0
# Fetching articles for category: clearing
# Number of articles fetched for clearing: 3
# Fetching articles for category: corporations
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: share
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: transfer
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: custodians
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: markets
# Number of articles fetched for markets: 5
# Fetching articles for category: ratings
# Number of articles fetched for ratings: 5
# Fetching articles for category: equity
# Number of articles fetched for equity: 5
# Fetching articles for category: commodity
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: currency
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: exchange
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: dissemination
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: advisory
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: market
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: fintechs
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: aggregation
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: biotechnology
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: blood
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: pressure
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: monitoring
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: machine
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: machines
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: scanners
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: supplies
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: injection
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: needles
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: syringe
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: gloves
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: care
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: nursing
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: homes
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: laboratories
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: scan
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: centres
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: healthcare
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: designing
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: maintenance
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: canals
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: dams
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: procurement
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: epc
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: projects
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: buildings
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: realty
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: civil
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: aerospace
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: farm
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: trucks
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: dumpers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: cranes
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: bulldozers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: generating
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: turbines
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: towers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: heavy
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: electrical
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: railway
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: wagons
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: emu
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: coaches
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: ship
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: building
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: cc
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: surveillance
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: access
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: intruder
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: fingerprint
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: locks
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: elevators
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: escalators
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: wires
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: telecommunication
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: castings
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: forgings
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: majority
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: packaging
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: cardboard
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: boxes
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: cans
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: drums
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: bottles
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: jars
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: pipes
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: glasses
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: abrasives
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: compressors
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: diesel
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: electrodes
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: refractories
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: individuals
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: corporates
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: automation
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: computer
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: hardware
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: computers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: laptops
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: servers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: motherboards
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: printers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: photo
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: copiers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: dredging
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: airlines
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: courier
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: movers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: packers
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: railways
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: shipping
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: transport
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: airports
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: airport
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: ports
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: bridge
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: highway
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: toll
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: road
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: highways
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: employment
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: pollution
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: trade
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: commission
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: agent
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: bpo)/
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: knowledge
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: kpo
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: bodies
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: city
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: town
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: authority
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: region
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: band
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: telephone
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: presence
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: water
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: supply
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: waste
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: emergency
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: brigade
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: flood
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: lines
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: cassette
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: recorder
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: dvd
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: player
# API Rate Limit Exceeded. Trying with another API key...
# Fetching articles for category: houseware
# API Rate Limit Exceeded. Trying with another API key...
#        Category                                      News Headline Sentiment
# 0     companies  How did the world run so low on cholera vaccin...  Negative
# 1     companies  India Enters The AI Race, With Plans Of Develo...   Neutral
# 2     companies  Mining Explosives and Systems Market to Reach ...   Neutral
# 3     companies  Select payments to units in IFSC exempted from...   Neutral
# 4     companies  AstraZeneca bets on licencing deals, public-pr...   Neutral
# ...         ...                                                ...       ...
# 1371     equity  The History of Public Health Colonialism ⋆ Bro...   Neutral
# 1372     equity  Shark Tank India 3: GenZ-inspired fashion bran...   Neutral
# 1373     equity  SAVENCIA FROMAGE & DAIRY: 2023 annual financia...   Neutral
# 1374     equity  SAVENCIA FROMAGE & DAIRY: 2023 annual financia...   Neutral
# 1375     equity  China Market Update: “Two Sessions” Drives Tec...   Neutral
#
# [1376 rows x 3 columns]

# %%
from fuzzywuzzy import process

# Get unique sectors from stock_df
unique_definitions = stock_df['Definition'].unique()

# Function to find the most similar sector for a given news headline
def find_similar_sector(headline, sectors):
    match = process.extractOne(headline, sectors)
    return match[0] if match else None

# Iterate through news_df to add Definition
for index, row in news_df.iterrows():
    headline = row['News Headline']
    definition = find_similar_sector(headline, unique_definitions)
    news_data['Definition'] = definition

final_news_df = pd.merge(news_data, stock_df[["Definition", "Ticker", "Name", "Sector"]], on="Definition", how="left")
final_news_df.drop(['Definition'], axis=1, inplace=True)

# Save the final dataframe to CSV
final_news_df.to_csv(r"C:\Users\DELL\Desktop\Projects\LOC 6.0\Final News DataFrame\Definition DataFrame.csv", index=False)
