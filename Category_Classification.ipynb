# %%
# Category list
category_list = [
    "Market Updates: General news and updates about the overall stock market, including indices such as the S&P 500, Dow Jones Industrial Average, and NASDAQ Composite.",
    "Earnings Reports: Information regarding the quarterly earnings of publicly traded companies.",
    "Company News: News related to specific companies, such as mergers and acquisitions, product launches, executive changes, and legal issues.",
    "Sector News: Updates on specific sectors within the stock market, such as technology, healthcare, finance, energy, and consumer goods.",
    "IPOs and Offerings: Information about initial public offerings (IPOs), secondary offerings, and other fundraising events by companies.",
    "Market Analysis: Expert analysis and opinions on market trends, performance, and forecasts.",
    "Global Markets: News related to international stock markets, including major indices and economic indicators from around the world.",
    "Economic Indicators: Reports on key economic indicators that may impact the stock market, such as unemployment rates, GDP growth, inflation, and interest rates.",
    "Commodities and Forex: Updates on commodity prices (such as gold, oil, and agricultural products) and foreign exchange rates.",
    "Regulatory News: Updates on regulatory changes, policy decisions, and investigations that may affect the stock market.",
    "Market Volatility: News related to market volatility, including sudden price fluctuations, trading halts, and market circuit breakers.",
    "Corporate Governance: News related to corporate governance practices, shareholder activism, and corporate social responsibility initiatives.",
    "Technical Analysis: Analysis of stock price movements and patterns using technical indicators and charting techniques.",
    "Investment Strategies: Information on different investment strategies, market trends, and portfolio management techniques.",
    "Personal Finance: Articles and advice on personal finance topics relevant to investing and managing wealth in the stock market.",
    "Market Sentiment: Insights into investor sentiment, including surveys, sentiment indices, and sentiment analysis tools.",
    "Market Events: Coverage of major events impacting the stock market, such as geopolitical tensions, natural disasters, and global pandemics.",
    "Dividends and Buybacks: Announcements of dividend payouts, stock buyback programs, and capital allocation strategies by companies.",
    "Market Innovations: News related to technological advancements, financial innovations, and disruptive trends shaping the stock market landscape.",
    "Market Regulations: Updates on regulatory developments, compliance requirements, and enforcement actions affecting the stock market.",
    "Market Psychology: Analysis of psychological factors influencing market behavior, such as fear, greed, and herd mentality.",
    "Market Education: Educational content aimed at informing investors about basic investing principles, market fundamentals, and investment strategies.",
    "Market Trends: Identification and analysis of emerging trends in the stock market, including thematic investing themes and market rotations.",
    "Market Disruptions: Coverage of disruptions to traditional markets, such as the rise of cryptocurrencies, decentralized finance (DeFi), and blockchain technology.",
    "Market Ethics: Discussions on ethical considerations in investing, corporate governance practices, and sustainability initiatives.",
    "Market Performance Metrics: Analysis of key performance metrics for individual stocks, sectors, and indices, such as price-to-earnings (P/E) ratios, earnings per share (EPS), and return on investment (ROI).",
    "Market Research: Reports and studies conducted by research firms, financial institutions, and industry experts on various aspects of the stock market.",
    "Market Outlook: Forecasts and predictions about future market trends, economic conditions, and investment opportunities.",
    "Market Technology: News related to technological advancements impacting trading platforms, algorithmic trading, high-frequency trading, and market infrastructure.",
    "Market Commentary: Opinions and analysis from market commentators, financial analysts, and investment strategists on current market developments and trends.",
    "Market Sentiment Indicators: Insights from sentiment indicators such as the VIX (Volatility Index), put/call ratios, and investor surveys, indicating market sentiment and potential market direction.",
    "Market Performance by Geography: Analysis of market performance in different regions and countries, including emerging markets, developed markets, and frontier markets.",
    "Market Events Calendar: A calendar of upcoming events, such as earnings releases, economic reports, and corporate events, that may impact the stock market.",
    "Market Risk Management: Strategies and techniques for managing risk in investment portfolios, including diversification, hedging, and risk-adjusted returns.",
    "Market Insider Trading: News and analysis of insider trading activities, including purchases and sales of company shares by insiders, such as executives and board members.",
    "Market Investment Vehicles: Information on various investment vehicles available to investors, including stocks, bonds, mutual funds, exchange-traded funds (ETFs), and derivatives.",
    "Market Quantitative Analysis: Analysis of market data using quantitative methods, such as statistical modeling, machine learning algorithms, and data mining techniques.",
    "Market Behavioral Finance: Exploration of behavioral biases and psychological factors influencing investor decision-making and market dynamics, such as loss aversion and herding behavior.",
    "Market Performance Benchmarks: Comparison of individual stock performance against relevant benchmarks, such as sector indices, market indices, and peer group comparisons.",
    "Market Crowdfunding and Crowdsourcing: Coverage of crowdfunding platforms and crowdsourcing initiatives in the stock market, enabling small investors to participate in investment opportunities.",
    "Market Philanthropy and Impact Investing: News and analysis of philanthropic initiatives, impact investing, and socially responsible investment (SRI) strategies within the stock market.",
    "Market Alternative Investments: Information on alternative investment opportunities, such as real estate investment trusts (REITs), commodities, private equity, and venture capital.",
    "Market Data Analytics: Utilization of big data analytics and data visualization techniques to derive insights from market data, such as market trends, trading patterns, and investor sentiment.",
    "Market Behavioral Economics: Examination of economic theories and principles applied to understand market behavior, including prospect theory, rational choice theory, and market efficiency hypotheses.",
    "Government Budget and Fiscal Policy: News and analysis of government budgets, fiscal policies, taxation changes, and spending priorities that may impact the economy and financial markets.",
    "Monetary Policy and Central Banks: Updates on monetary policy decisions, interest rate changes, and interventions by central banks, such as the Federal Reserve, European Central Bank, and Bank of Japan.",
    "Government Regulations and Policies: Coverage of regulatory developments, policy changes, and legislative initiatives affecting industries, markets, and companies.",
    "Trade Policies and Tariffs: News related to trade agreements, tariffs, trade disputes, and trade policy shifts that may influence international trade flows and market sentiment.",
    "Geopolitical Events and Risks: Analysis of geopolitical developments, conflicts, diplomatic tensions, and geopolitical risks that could impact global markets and investor confidence.",
    "Environmental, Social, and Governance (ESG) Investing: Coverage of ESG-related trends, corporate sustainability initiatives, environmental regulations, and socially responsible investment strategies.",
    "Climate Change and Market Impacts: News and analysis of climate change-related risks and opportunities for investors, including regulatory changes, carbon pricing, and shifts in consumer preferences.",
    "Healthcare Policies and Regulations: Updates on healthcare policies, regulatory approvals, drug pricing regulations, and healthcare reforms impacting pharmaceutical, biotech, and healthcare companies.",
    "Education and Training: Resources and information for investors, traders, and financial professionals to improve their knowledge and skills in investing, trading, and financial analysis.",
    "Labor Market and Employment Trends: Analysis of labor market conditions, unemployment rates, job growth, wage trends, and workforce demographics influencing consumer spending and economic growth.",
    "Education and Training: Resources and information for investors, traders, and financial professionals to improve their knowledge and skills in investing, trading, and financial analysis.",
    "Emerging Technologies and Innovation: Coverage of emerging technologies such as artificial intelligence, blockchain, 5G, and biotechnology, and their potential impact on industries and investment opportunities.",
    "Cybersecurity and Data Privacy: News and analysis of cybersecurity threats, data breaches, regulatory compliance, and privacy concerns affecting companies and investors.",
    "Infrastructure Development and Investments: Updates on infrastructure projects, government spending on infrastructure, public-private partnerships, and infrastructure investment opportunities.",
    "Energy Policies and Renewable Energy: Coverage of energy policies, regulations, subsidies, and market trends in traditional and renewable energy sectors, including solar, wind, and electric vehicles.",
    "Consumer Trends and Behavior: Analysis of consumer preferences, spending patterns, demographic shifts, and market trends influencing consumer-oriented industries such as retail, hospitality, and e-commerce."
]

# Using list comprehension to split each element and save the first part
filtered_list = [element.split(":")[0] for element in category_list]

filtered_list
# Out:
# ['Market Updates',
#  'Company News',
#  'Sector News',
#  'IPOs and Offerings',
#  'Market Analysis',
#  'Market Innovations',
#  'Market Outlook',
#  'Market Technology',
#  'Market Commentary',
#  'Market Quantitative Analysis',
#  'Market Behavioral Finance',
#  'Market Performance Benchmarks',
#  'Market Crowdfunding and Crowdsourcing',
#  'Market Philanthropy and Impact Investing',
#  'Market Alternative Investments',
#  'Market Data Analytics',
#  'Market Behavioral Economics',
#  'Government Regulations and Policies',
#  'Trade Policies and Tariffs',
#  'Environmental, Social, and Governance (ESG) Investing',
#  'Climate Change and Market Impacts',
#  'Healthcare Policies and Regulations',
#  'Education and Training',
#  'Labor Market and Employment Trends',
#  'Infrastructure Development and Investments',
#  'Energy Policies and Renewable Energy',
#  'Consumer Trends and Behavior']
